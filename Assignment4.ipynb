# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenize

# USING_PORTION = slice(None, 80) # When training
# USING_PORTION = slice(80, None) # When testing
USING_PORTION = slice(0, 100)

# %%
dataset = []
with open('./dataset/dataset.txt', encoding='utf-8') as data_file:
    dataset = data_file.readlines()

dataset = [data.strip() for data in dataset]

print("================ LOADING DATASET ================")
print('\n'.join(dataset[:5]))
# Out:
# ================ LOADING DATASET ================
# Poly- and perfluorinated compounds activate human pregnane X receptor.
# Neurotransmitters activate T-cells and elicit crucial functions via neurotransmitter receptors
# Pericytes activate complement in fibrosis
# These molecules activate different signaling pathways and produce different physiological responses which can be taken advantage of for sepsis modeling.
# Monoamines activate neuropeptide signaling cascades to modulate nociception in C. elegans

# %%
import re

# To mitigate pos_tag wrongly tags
#     If these words appear, force tag it as 'V'
verbs = [
    'activate', 'inhibit', 'bind',
    'accelerate', 'augment', 'induce', 'stimulate', 'require', 'up-regulate',
    'abolish', 'block', 'down-regulate', 'prevent'
]

remove_paren = re.compile(r"\(.*?\)")
dataset_preprocessed = [
    remove_paren.sub('', sentence)
    for sentence in dataset
]

dataset_tagged = [
    [
        (word, tag) if word not in verbs else (word, 'V')
        for word, tag in pos_tag(word_tokenize(sentence))
    ]
    for sentence in dataset_preprocessed
]

print("================ TAGGING DATASET ================")
print('\n'.join([ str(dataset) for dataset in dataset_tagged[:5] ]))
# Out:
# ================ TAGGING DATASET ================
# [('Poly-', 'NNP'), ('and', 'CC'), ('perfluorinated', 'VBD'), ('compounds', 'NNS'), ('activate', 'V'), ('human', 'JJ'), ('pregnane', 'NN'), ('X', 'NNP'), ('receptor', 'NN'), ('.', '.')]
# [('Neurotransmitters', 'NNS'), ('activate', 'V'), ('T-cells', 'NNS'), ('and', 'CC'), ('elicit', 'JJ'), ('crucial', 'JJ'), ('functions', 'NNS'), ('via', 'IN'), ('neurotransmitter', 'NN'), ('receptors', 'NNS')]
# [('Pericytes', 'NNS'), ('activate', 'V'), ('complement', 'NN'), ('in', 'IN'), ('fibrosis', 'NN')]
# [('These', 'DT'), ('molecules', 'NNS'), ('activate', 'V'), ('different', 'JJ'), ('signaling', 'NN'), ('pathways', 'NNS'), ('and', 'CC'), ('produce', 'VB'), ('different', 'JJ'), ('physiological', 'JJ'), ('responses', 'NNS'), ('which', 'WDT'), ('can', 'MD'), ('be', 'VB'), ('taken', 'VBN'), ('advantage', 'NN'), ('of', 'IN'), ('for', 'IN'), ('sepsis', 'NN'), ('modeling', 'NN'), ('.', '.')]
# [('Monoamines', 'NNS'), ('activate', 'V'), ('neuropeptide', 'IN'), ('signaling', 'VBG'), ('cascades', 'NNS'), ('to', 'TO'), ('modulate', 'VB'), ('nociception', 'NN'), ('in', 'IN'), ('C.', 'NNP'), ('elegans', 'NNS')]

# %%
from nltk import CFG
from nltk.parse import ChartParser
from nltk.grammar import Nonterminal, Production

grammar = CFG.fromstring('\n'.join([
    'S -> NP VP | NP VP NP | S C S | S "." | VP NP | WDT S | EX S | S RB | S PART | IN S',
    'NP -> N | DT NP | J NP | NP NP | NP MOD | NP C NP | NP R | R NP | PART | NP POS | WRONG_NP',
    'VP -> V | R VP | MD VP | VP PART | VP C VP | VP MOD',
    'MOD -> IN NP | IN IN NP | TO VP | TO NP',
    'PART -> VBN | VBG',
    'C -> CC | ","',
    'N -> NN | NNP | NNS | FW | CD | PRP | WRONG_N',
    'R -> RB | RBR | RBS | RP | R C R',
    'V -> VB | VBD | VBP | VBZ',
    'J -> JJ | JJR | JJS | J C J',
    'WRONG_NP -> JJ | R V | NNP VBZ'
])).productions()


# Append pos_tagged results into originally defined grammar
def generate_sent_grammar(sent):
    sent_grammar = grammar[:]
    sent_words = list([word for word, tag in sent])
    
    for word, tag in sent:
        sent_grammar.append(Production(
            Nonterminal(tag), (word, )
        ))
    
    return sent_grammar, sent_words

    
non_sents = {}
parsed_sents = {}
# Parse dataset
for (idx, sent) in enumerate(dataset_tagged[USING_PORTION]):
    sent_grammar, sent_words = generate_sent_grammar(sent)
    
    parser = ChartParser(CFG(Nonterminal('S'), sent_grammar))
    tree = parser.parse_one(sent_words)
    
    if tree is None:
        non_sents[idx] = sent
    
    else:
        parsed_sents[idx] = tree

print("Parsed %d sents, Unable to parse %d sents" % (len(parsed_sents), len(non_sents)))
# Out:
# Parsed 73 sents, Unable to parse 27 sents

# %%
result = {}

# Summarize NP into a string
def summarize_np(tree):
    if tree.label() != 'NP':
        return ''
    
    # NP -> N
    if tree[0].label() == 'N':
        return tree[0][0][0]
    
    # NP -> DT NP | J NP | R NP 
    if tree[0].label() in ('J', 'DT', 'R'):
        return summarize_np(tree[1])
    
    # NP -> PART
    if tree[0].label() == 'PART':
        return tree[0][0][0]
    
    # NP -> WRONG_NP
    # WRONG_NP: Originally, it should not be classified into NP
    #           but it is classified as NP to mitigate not correctly tagged sentence
    if tree[0].label() == 'WRONG_NP':
        if tree[0][0].label() == 'JJ':
            return tree[0][0][0]
        
        if tree[0][0].label() == 'R':
            return tree[0][1][0][0]
        
        if tree[0][0].label() == 'NNP':
            return tree[0][0][0] + ' ' + tree[0][1][0]
    
    if len(tree) < 2:
        return ''
    
    # NP-> NP R | NP MOD
    if tree[1].label() in ('MOD', 'R'):
        return summarize_np(tree[0])

    # NP -> NP C NP
    if tree[1].label() == 'C':
        return summarize_np(tree[0]) + ',' + summarize_np(tree[2])

    # NP -> NP POS 
    if tree[1].label() == 'POS':
        return summarize_np(tree[0]) + ' ' + tree[1][0]

    # NP -> NP NP
    if tree[1].label() == 'NP' and tree[0].label() == 'NP':
        return summarize_np(tree[0]) + ' ' + summarize_np(tree[1])
    
    return ''

# Summarize VP into a string
def summarize_vp(tree):
    # VP -> V
    if tree[0].label() == 'V':
        if isinstance(tree[0][0], str):
            return tree[0][0]
        
        # V -> VB | VBD | VBP | VBZ
        return tree[0][0][0]
    
    # VP -> R VP | MD VP
    if tree[1].label() == 'VP':
        return summarize_vp(tree[1])
    
    # VP -> VP C VP 
    if tree[1].label() == 'C':
        return summarize_vp(tree[0]) + ',' + summarize_vp(tree[2])
    
    # VP -> VP PART | VP MOD
    if tree[0].label() == 'VP':
        return summarize_vp(tree[0])
    
    return ''

# Summarize S into an array of { X: String, V: String, Z: String }
def summarize_s(tree):
    # S -> NP VP | NP VP NP 
    if tree[0].label() == 'NP':
        np = summarize_np(tree[0])
        vp = summarize_vp(tree[1])
        np_2 = ''
        
        # S -> NP VP
        if len(tree) <= 2:
            # S -> NP (VP -> VP MOD)
            if tree[1][1].label() == 'MOD':
                np_2 = summarize_np(tree[1][1][1])
        
        # S -> NP VP NP
        else:
            np_2 = summarize_np(tree[2])
        
        if np_2 == '':
            return []
        
        return [{ 'X': np, 'V': vp, 'Y': np_2 }]
    
    # S -> S "."
    if isinstance(tree[1], str):
        return summarize_s(tree[0])
    
    # S -> S C S
    if tree[1].label() == 'C':
        return summarize_s(tree[0]) + summarize_s(tree[2])
    
    # S -> VP NP
    if tree[0].label() == 'VP':
        return []
    
    # S -> S RB | S PART
    if tree[0].label() == 'S':
        return summarize_s(tree[0])
    
    # S -> WDT S | EX S | IN S
    if tree[1].label() == 'S':
        return summarize_s(tree[1])
    
    return []


for idx, tree in parsed_sents.items():
    values = summarize_s(tree)
    
    # if len(result[idx]) == 0:
        # tree.pretty_print()
    
    new_values = []
    # Change { X: 'a,b', V: 'bind', Y: 'c'} to
    #        { X: 'a', V: 'bind', Y: 'c'}, { X: 'b', V: 'bind', Y: 'c'}
    
    for value in values:
        xs = value['X'].split(',')
        ys = value['Y'].split(',')
        
        for x in xs:
            for y in ys:
                new_values.append({'X': x, 'V': value['V'], 'Y': y})
    
    result[idx] = new_values


# Parse NP to str
def parse_np(subsent):
    np_grammar, np_words = generate_sent_grammar(subsent)
    
    parser = ChartParser(CFG(Nonterminal('NP'), np_grammar))
    tree = parser.parse_one(np_words)
    
    if tree is None:
        return ' '.join(np_words)
    
    return summarize_np(tree)

# If given sentence could not be parsed, split it into two parts using the verb.
# Then, try to parse the parts as NP
#     If it also fails, just return splitted.
for idx, non_sent in non_sents.items():
    verb_cands = list([ (word, tag) for word, tag in non_sent if tag == 'V' ])
    if len(verb_cands) == 0:
        verb_cands = list([ (word, tag) for word, tag in non_sent if tag.startswith('V') ])
    
    if len(verb_cands) == 0:
        result[idx] = [{'X': '', 'V': '', 'Y': ''}]
        continue
    
    verb = verb_cands[0]
    verb_idx = non_sent.index(verb)
    
    # Split into two parts
    sub_raw = non_sent[:verb_idx]
    obj_raw = non_sent[verb_idx + 1:]
    
    sub = parse_np(sub_raw)
    obj = parse_np(obj_raw)
    
    result[idx] = [{
        'X': sub,
        'V': verb[0],
        'Y': obj
    }]

# Print extracted result
import json
with open('./output.txt', 'w', encoding='utf-8') as f:
    for index, values in sorted(result.items(), key = lambda x: x[0]):
        value_serialized = json.dumps(values)
        
        f.write(value_serialized + '\n')
        print(index, value_serialized)
# Out:
# 0 [{"X": "Poly- and perfluorinated compounds", "V": "activate", "Y": "human pregnane X receptor ."}]
# 1 [{"X": "Neurotransmitters", "V": "activate", "Y": "T-cells"}, {"X": "Neurotransmitters", "V": "activate", "Y": "functions receptors"}]
# 2 [{"X": "Pericytes", "V": "activate", "Y": "complement"}]
# 3 [{"X": "molecules", "V": "activate", "Y": "different signaling pathways and produce different physiological responses which can be taken advantage of for sepsis modeling ."}]
# 4 [{"X": "Monoamines", "V": "activate", "Y": "elegans"}]
# 5 [{"X": "bacteria", "V": "activate", "Y": "interferon production"}]
# 6 [{"X": "Salient sounds", "V": "activate", "Y": "human visual cortex automatically ."}]
# 7 [{"X": "Bisphenol A and its analogues", "V": "activate", "Y": "human pregnane X receptor ."}]
# 8 [{"X": "cancer vaccination", "V": "activate", "Y": "T-cell responses"}, {"X": "cells", "V": "activate", "Y": "T-cell responses"}]
# 9 [{"X": "Because the subthreshold sequences", "V": "activate", "Y": "the retina at stimulation rates that would typically induce strong fading , such retinal 'tickling ' has the potential to minimize the fading problem"}]
# 10 [{"X": "Instead of achieving reward through adaptive behaviors , drugs of abuse directly", "V": "activate", "Y": "the reward pathways ."}]
# 11 [{"X": "Cannabinoids", "V": "activate", "Y": "signaling Key C. elegans behaviors"}]
# 12 [{"X": "Integrins", "V": "activate", "Y": "transcription factor-kappaB"}, {"X": "cytokines", "V": "activate", "Y": "transcription factor-kappaB"}]
# 13 [{"X": "Enhancer elements", "V": "activate", "Y": "3 ' splice site 2"}]
# 14 [{"X": "actions", "V": "activate", "Y": "sulcus"}, {"X": "actions", "V": "activate", "Y": "fusiform gyrus perceptual cues"}]
# 15 [{"X": "Muscarinic acetylcholine receptors", "V": "activate", "Y": "acetylcholinesterase gene promoter"}]
# 16 [{"X": "Anti-cyclic citrullinated peptide antibodies from rheumatoid arthritis patients", "V": "activate", "Y": "complement via both the classical and alternative pathways ."}]
# 17 [{"X": "ions", "V": "activate", "Y": "nitroalkenes bonding"}]
# 18 [{"X": "Anti-capsular antibodies", "V": "activate", "Y": "killing of Escherichia coli O8 : K87 by the alternate complement pathway in porcine serum ."}]
# 19 [{"X": "compounds", "V": "activate", "Y": "TRPA1 ion channels"}]
# 20 [{"X": "Bacterial polysaccharides", "V": "inhibit", "Y": "hyperglycemia"}]
# 21 [{"X": "Iridoids nucleus", "V": "inhibit", "Y": "inflammation"}, {"X": "Iridoids nucleus", "V": "inhibit", "Y": "stress NF-\u03baB pathway"}]
# 22 [{"X": "pseudomonads", "V": "inhibit", "Y": "Oomycete plant pathogens max"}]
# 23 [{"X": "Phenformin,metformin", "V": "inhibit", "Y": "growth and migration of LN229 glioma cells in vitro and in vivo ."}]
# 24 [{"X": "Bone marrow-derived mesenchymal stem cells", "V": "inhibit", "Y": "T follicular helper cell mice"}]
# 25 [{"X": "Bufadienolides", "V": "inhibit", "Y": "cell proliferation"}, {"X": "Bufadienolides", "V": "inhibit", "Y": "arrest cells phase"}]
# 26 [{"X": "Flavonoids", "V": "inhibit", "Y": "enzymes"}, {"X": "Flavonoids", "V": "inhibit", "Y": "production"}]
# 27 [{"X": "Procyanidins", "V": "inhibit", "Y": "angiogenesis extracellular matrix"}]
# 28 [{"X": "hydrophobic aggregates", "V": "inhibit", "Y": "formation"}]
# 29 [{"X": "Cytotropic heterogeneous molecular lipids", "V": "inhibit", "Y": "growth cells"}]
# 30 [{"X": "Oxathiazolones", "V": "inhibit", "Y": "immunoproteasome"}]
# 31 [{"X": "Largazole and its derivatives selectively", "V": "inhibit", "Y": "ubiquitin activating enzyme ."}]
# 32 [{"X": "Jun proteins", "V": "inhibit", "Y": "autophagy"}]
# 33 [{"X": "Axl-148b chimeric aptamers", "V": "inhibit", "Y": "cancer"}, {"X": "Axl-148b chimeric aptamers", "V": "inhibit", "Y": "melanoma progression"}]
# 34 [{"X": "receptor 2 agonists", "V": "inhibit", "Y": "fibrocyte differentiation"}]
# 35 [{"X": "Ebola virus VP24 proteins", "V": "inhibit", "Y": "interaction karyopherin alpha proteins STAT1"}]
# 36 [{"X": "Hawthorn extracts", "V": "inhibit", "Y": "LDL oxidation"}]
# 37 [{"X": "membranes", "V": "inhibit", "Y": "prostaglandin"}, {"X": "membranes", "V": "inhibit", "Y": "contractions"}]
# 38 [{"X": "monocytes", "V": "inhibit", "Y": "multiplication pneumophila"}]
# 39 [{"X": "Heparin", "V": "inhibit", "Y": "zymosan"}, {"X": "Heparin", "V": "inhibit", "Y": "cobra venom factor activation"}, {"X": "derivatized heparin", "V": "inhibit", "Y": "zymosan"}, {"X": "derivatized heparin", "V": "inhibit", "Y": "cobra venom factor activation"}]
# 40 [{"X": "In contrast ,", "V": "amphetamine", "Y": "only binds to the N-terminus ."}]
# 41 [{"X": "Type I inhibitors", "V": "bind", "Y": "to the active protein kinase conformation ."}]
# 42 [{"X": "TALE proteins", "V": "bind", "Y": "chromatin"}]
# 43 [{"X": "exon 1 amyloid fibrils", "V": "bind", "Y": "laterally to the cellular membrane ."}]
# 44 [{"X": "Catecholamines", "V": "bind", "Y": "to enkephalins , morphiceptin , and morphine ."}]
# 45 [{"X": "Acanthamoebae", "V": "bind", "Y": "epithelium"}]
# 46 [{"X": "Bordetella pertussis fimbriae", "V": "bind", "Y": "monocytes FimD"}]
# 47 [{"X": "pathogenic bacteria", "V": "bind", "Y": "specifically to the carbohydrate sequence GalNAc beta 1-4Gal found in some glycolipids ."}]
# 48 [{"X": "TTAGGG repeat factors 1", "V": "bind", "Y": "subset"}, {"X": "TTAGGG repeat factors 1", "V": "bind", "Y": "repeats"}, {"X": "2", "V": "bind", "Y": "subset"}, {"X": "2", "V": "bind", "Y": "repeats"}]
# 49 [{"X": "membrane-bound", "V": "bind", "Y": "bacteria"}, {"X": "forms", "V": "bind", "Y": "bacteria"}]
# 50 [{"X": "Anti-ribosomal and ' P-peptide'-specific autoantibodies", "V": "bind", "Y": "to T lymphocytes ."}]
# 51 [{"X": "CD3+ thymocytes", "V": "bind", "Y": "cells"}]
# 52 [{"X": "Sulfoglucuronyl glycolipids", "V": "bind", "Y": "laminin"}]
# 53 [{"X": "Hyaluronate binding proteins", "V": "bind", "Y": "to fibronectin , laminin and collagen ."}]
# 54 [{"X": "Microvesicles", "V": "bind", "Y": "soluble fibrinogen , adhere to immobilized fibrinogen and coaggregate with platelets ."}]
# 55 [{"X": "Falciparum malaria-infected erythrocytes", "V": "bind", "Y": "cells"}]
# 56 [{"X": "monomer", "V": "bind", "Y": "TLR-2"}, {"X": "peptides", "V": "bind", "Y": "TLR-2"}]
# 57 [{"X": "Scorpion toxins affecting sodium current inactivation", "V": "bind", "Y": "receptor sites channels"}]
# 58 [{"X": "fingers", "V": "bind", "Y": "DNA"}]
# 59 [{"X": "Enzymes", "V": "bind", "Y": "substrates at key locations in their structure called active sites"}]
# 60 [{"X": "Obesity", "V": "accelerate", "Y": "aging process"}]
# 61 [{"X": "Antioxidants", "V": "accelerate", "Y": "lung cancer progression"}]
# 62 [{"X": "Grooves", "V": "accelerate", "Y": "dew shedding"}]
# 63 [{"X": "proton bunches", "V": "accelerate", "Y": "electrons"}]
# 64 [{"X": "Rat", "V": "accelerate", "Y": "osteogenesis"}, {"X": "exosomes", "V": "accelerate", "Y": "osteogenesis"}]
# 65 [{"X": "TFS", "V": "accelerate", "Y": "transcription"}, {"X": "Spt4/5", "V": "accelerate", "Y": "transcription"}]
# 66 [{"X": "Eosinophils", "V": "accelerate", "Y": "pathogenesis of psoriasis by supporting an inflammatory milieu that promotes neutrophil infiltration ."}]
# 67 [{"X": "Lipid membranes", "V": "accelerate", "Y": "formation model amyloidosis"}]
# 68 [{"X": "Homocysteine", "V": "accelerate", "Y": "skin"}]
# 69 [{"X": "NLRP3 inflammasome", "V": "accelerate", "Y": "mediated pathology hepatitis"}, {"X": "IL-1\u03b2", "V": "accelerate", "Y": "mediated pathology hepatitis"}]
# 70 [{"X": "glucosamine fibers", "V": "accelerate", "Y": "hemostasis treated drugs"}]
# 71 [{"X": "administered adipose-derived stem cells", "V": "accelerate", "Y": "healing"}, {"X": "administered adipose-derived stem cells", "V": "accelerate", "Y": "vasculogenesis"}]
# 72 [{"X": "Cumulus cells", "V": "accelerate", "Y": "factor"}]
# 73 [{"X": "Aluminium salts", "V": "accelerate", "Y": "peroxidation"}]
# 74 [{"X": "foundations", "V": "accelerate", "Y": "change"}, {"X": "foundations", "V": "accelerate", "Y": "competence"}]
# 75 [{"X": "Gangliosides", "V": "accelerate", "Y": "rat neonatal learning"}, {"X": "Gangliosides", "V": "accelerate", "Y": "levels acetylcholinesterases"}]
# 76 [{"X": "Semax", "V": "accelerate", "Y": "healing"}, {"X": "glyproline peptides", "V": "accelerate", "Y": "healing"}]
# 77 [{"X": "Faulty engines cells", "V": "accelerate", "Y": "ageing"}, {"X": "Faulty engines cells", "V": "accelerate", "Y": "disease"}]
# 78 [{"X": "MIF-1", "V": "accelerate", "Y": "neuromotor"}, {"X": "MIF-1", "V": "accelerate", "Y": "EEG"}, {"X": "MIF-1", "V": "accelerate", "Y": "development"}]
# 79 [{"X": "Distributed representations", "V": "accelerate", "Y": "evolution"}]
# 80 [{"X": "Azeloglycine", "V": "down-regulate", "Y": "mediators"}, {"X": "nicotinamide", "V": "down-regulate", "Y": "mediators"}]
# 81 [{"X": "miR-214", "V": "down-regulate", "Y": "Necl-2/CADM1"}, {"X": "hypoxia", "V": "down-regulate", "Y": "Necl-2/CADM1"}]
# 82 [{"X": "let-7", "V": "down-regulate", "Y": "axon-guidance genes Ntn1"}, {"X": "let-7", "V": "down-regulate", "Y": "Dcc nerve regeneration"}, {"X": "miR-9", "V": "down-regulate", "Y": "axon-guidance genes Ntn1"}, {"X": "miR-9", "V": "down-regulate", "Y": "Dcc nerve regeneration"}]
# 83 [{"X": "Ultrafine carbon particles", "V": "down-regulate", "Y": "CYP1B1 expression in human monocytes ."}]
# 84 [{"X": "Probiotics", "V": "down-regulate", "Y": "genes in Salmonella enterica serovar typhimurium pathogenicity islands 1 and 2 ."}]
# 85 [{"X": "polyphenols", "V": "down-regulate", "Y": "stress protein tuberculosis"}]
# 86 [{"X": "bmo-miR-0001", "V": "down-regulate", "Y": "expression gene"}, {"X": "bmo-miR-0015", "V": "down-regulate", "Y": "expression gene"}]
# 87 [{"X": "suppressor cells", "V": "down-regulate", "Y": "expression"}, {"X": "suppressor cells", "V": "down-regulate", "Y": "CD8+ T cells"}]
# 88 [{"X": "Glucocorticoids", "V": "down-regulate", "Y": "somatostatin receptors"}]
# 89 [{"X": "Glucocorticoids", "V": "down-regulate", "Y": "the extracellular matrix proteins fibronectin , fibulin-1 and fibulin-2 in bone marrow stroma ."}]
# 90 [{"X": "memory CTL", "V": "down-regulate", "Y": "molecule expression following virus clearance"}]
# 91 [{"X": "MiR-126 restoration", "V": "down-regulate", "Y": "VEGF and inhibit the growth of lung cancer cell lines in vitro and in vivo ."}]
# 92 [{"X": "miR-26a,miR-214", "V": "down-regulate", "Y": "expression of the PTEN gene in chronic lymphocytic leukemia , but not PTEN mutation or promoter methylation ."}]
# 93 [{"X": "IL-12", "V": "down-regulate", "Y": "B cell migration manner"}, {"X": "IL-18", "V": "down-regulate", "Y": "B cell migration manner"}]
# 94 [{"X": "VIP", "V": "down-regulate", "Y": "CXCL10"}, {"X": "PACAP", "V": "down-regulate", "Y": "CXCL10"}]
# 95 [{"X": "concentrations", "V": "down-regulate", "Y": "agonist induced secretion"}]
# 96 [{"X": "Flavonoids from Theobroma cacao", "V": "down-regulate", "Y": "inflammatory mediators ."}]
# 97 [{"X": "Motif Ligand 1 cells", "V": "down-regulates", "Y": "the invasion of their metastatic melanoma cells ."}]
# 98 [{"X": "Two independent mechanisms", "V": "down-regulate", "Y": "SecA ATPase activity"}]
# 99 [{"X": "metabolites", "V": "down-regulate", "Y": "receptor gamma"}]

# %%
import csv
with open('dataset/dataset_annotations.csv', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    rows = list(reader)

true_positive = 0
false_positive = 0
false_negative = 0

for idx, (annotations, _) in enumerate(rows[USING_PORTION]):
    groundtruth = set()
    for triplet in json.loads(annotations):
        groundtruth.add(
            (triplet['X'], triplet['V'], triplet['Y'])
        )

    predicted = set()
    for triplet in result[idx]:
        predicted.add(
            (triplet['X'], triplet['V'], triplet['Y'])
        )
    
    true_positive += len(groundtruth & predicted)
    false_positive += len(predicted - groundtruth)
    false_negative += len(groundtruth - predicted)

precision = true_positive / (true_positive + false_positive)
recall = true_positive / (true_positive + false_negative)

if precision + recall == 0:
    f_score = 0

else:
    f_score = 2 * (precision * recall) / (precision + recall)


print("TP       : %d"   % true_positive)
print("FP       : %d"   % false_positive)
print("FN       : %d"   % false_negative)
print("Precision: %.4f" % precision)
print("Recall   : %.4f" % recall)
print("F Score  : %.4f" % f_score)
# Out:
# ERROR Poly- and perfluorinated compounds activate human pregnane X receptor.
# [{"X": "Neurotransmitters", "V": "activate", "Y": "T-cells"}]
# [{"X": "Pericytes", "V": "activate", "Y": "complement"}]
# [{"X": "Molecules", "V": "activate", "Y": "different signaling pathways"}]
# [{"X": "Monoamines", "V": "activate", "Y": "neuropeptide signaling cascades"}]
# [{"X": "bacteria", "V": "activate", "Y": "type-I interferon production"}]
# [{"X": "Salient sounds", "V": "activate", "Y": "human visual cortex"}]
# [{"X": "Bisphenol A", "V": "activate", "Y": "human pregnane X receptor"}, {"X": "analogues", "V": "activate", "Y": "human pregnane X receptor"}]
# [{"X": "cells", "V": "activate", "Y": "T-cell responses"}]
# [{"X": "substhreshold sequences", "V": "activate", "Y": "retina"}]
# [{"X": "drugs", "V": "activate", "Y": "reward pathways"}]
# [{"X": "Cannabinoids", "V": "activate", "Y": "signaling"}]
# [{"X": "Integrins", "V": "activates", "Y": "nuclear transcription factor-kappaB"}, {"X": "cytokines", "V": "activates", "Y": "nuclear transcription factor-kappaB"}]
# [{"X": "Enhancer elements", "V": "activate", "Y": "3' splice site"}]
# [{"X": "actions", "V": "activate", "Y": "sulcus"}, {"X": "actions", "V": "activate", "Y": "fusiform gyrus"}]
# [{"X": "Muscarinic acetylcholine receptors", "V": "activate", "Y": "acetylcholinesterase gene promoter"}]
# [{"X": "peptide antibodies", "V": "activate", "Y": "complement"}]
# [{"X": "2-Aminopyridinium ions", "V": "activate", "Y": "nitroalkenes"}]
# [{"X": "antibodies", "V": "activate", "Y": "killing"}]
# [{"X": "compounds", "V": "activate", "Y": "TRPA1 ion channels"}]
# [{"X": "Bacterial polysaccharides", "V": "inhibit", "Y": "hyperglycemia"}]
# [{"X": "Iridoids", "V": "inhibit", "Y": "inflammation"}, {"X": "Iridoids", "V": "inhibit", "Y": "stress"}]
# ERROR Aquatic pseudomonads inhibit Oomycete plant pathogens of glycine max.
# [{"X": "Phenformin", "V": "inhibit", "Y": "growth"}, {"X": "metformin", "V": "inhibit", "Y": "growth"}, {"X": "Phenformin", "V": "inhibit", "Y": "migration"}, {"X": "metformin", "V": "inhibit", "Y": "migration"}]
# [{"X": "stem cells", "V": "inhibit", "Y": "T follicular helper cell"}]
# [{"X": "Bufadienolides", "V": "inhibit", "Y": "cell proliferation"}]
# [{"X": "Flavonoids", "V": "inhibit", "Y": "COX-1"}, {"X": "Flavonoids", "V": "inhibit", "Y": "COX-2 enzymes"}, {"X": "Flavonoids", "V": "inhibit", "Y": "cytokine/chemokine production"}]
# [{"X": "Procyanidins", "V": "inhibit", "Y": "tumor aniogenesis"}]
# [{"X": "hydrophobic aggregates", "V": "inhibit", "Y": "ice formation"}]
# [{"X": "molecular lipids", "V": "inhibit", "Y": "growth"}]
# [{"X": "Oxathiazolones", "V": "inhibit", "Y": "immunoproteasome"}]
# [{"X": "Largazole", "V": "inhibit", "Y": "ubiquitin activating enzyme"}, {"X": "derivatives", "V": "inhibit", "Y": "ubiquitin activating enzyme"}]
# [{"X": "Jun proteins", "V": "inhibit", "Y": "autophagy"}]
# [{"X": "Axl-148b chimeric aptamers", "V": "inhibit", "Y": "breast cancer"}, {"X": "Axl-148b chimeric aptamers", "V": "inhibit", "Y": "melanoma progression"}]
# [{"X": "Toll-like receptor 2 agonists", "V": "inhibit", "Y": "human fibrocyte differntiation"}]
# [{"X": "Ebola virus VP 24 proteins", "V": "inhibit", "Y": "interaction"}]
# [{"X": "Hawthorn extracts", "V": "inhibit", "Y": "LDL oxidation"}]
# [{"X": "membranes", "V": "inhibit", "Y": "prostaglandin"}]
# [{"X": "monocytes", "V": "inhibit", "Y": "multiplication"}]
# [{"X": "Heparin", "V": "inhibit", "Y": "zymosan"}, {"X": "Heparin", "V": "inhibit", "Y": "cobra venom factor activation"}]
# [{"X": "amphetamine", "V": "binds", "Y": "N-terminus"}]
# [{"X": "Type I inhibitors", "V": "bind", "Y": "active protein kinase conformation"}]
# [{"X": "TALE proteins", "V": "bind", "Y": "chromatin"}]
# [{"X": "\u03b1-Synuclein", "V": "bind", "Y": "celluar membrane"}, {"X": "huntingtin exon 1 amyloid fibrils", "V": "bind", "Y": "cellular membrane"}]
# [{"X": "Catecholamines", "V": "bind", "Y": "enkephalins"}, {"X": "Catecholamines", "V": "bind", "Y": "morphiceptin"}, {"X": "Catecholamines", "V": "bind", "Y": "morphine"}]
# [{"X": "Acanthamoebae", "V": "bind", "Y": "rabbit corneal epithelium"}]
# [{"X": "Bordetella pertussis fimbriae", "V": "bind", "Y": "motocytes"}]
# [{"X": "pathogenic bacteria", "V": "bind", "Y": "carbohydrate sequence"}]
# [{"X": "TTAGGG repeat factors 1 and 2", "V": "bind", "Y": "subset"}]
# [{"X": "forms", "V": "bind", "Y": "bacteria"}]
# [{"X": "autoantibodies", "V": "bind", "Y": "T lymphocytes"}]
# [{"X": "CD3+ thymocytes", "V": "bind", "Y": "cells"}]
# [{"X": "Sulfoglucuronyl glycolipids", "V": "bind", "Y": "laminin"}]
# [{"X": "proteins", "V": "bind", "Y": "fibronectin"}, {"X": "proteins", "V": "bind", "Y": "laminin"}, {"X": "proteins", "V": "bind", "Y": "collagen"}]
# [{"X": "Microvesicles", "V": "bind", "Y": "soluble fibrinogen"}]
# [{"X": "Falciparum malaria-infected erythrocytes", "V": "bind", "Y": "cells"}]
# [{"X": "monemer", "V": "bind", "Y": "TLR-2"}, {"X": "peptides", "V": "bind", "Y": "TLR-2"}]
# [{"X": "scorpion toxins", "V": "bind", "Y": "receptor sites"}]
# [{"X": "fingers", "V": "bind", "Y": "DNA"}]
# [{"X": "Enzymes", "V": "bind", "Y": "subrates"}]
# [{"X": "Obesity", "V": "accelerate", "Y": "aging process"}]
# [{"X": "Antioxidants", "V": "accelerate", "Y": "lung cancer progression"}]
# [{"X": "Grooves", "V": "accelerate", "Y": "dew shedding"}]
# [{"X": "proton bunches", "V": "accelerate", "Y": "electrons"}]
# [{"X": "exosomes", "V": "accelerate", "Y": "osteogenesis"}]
# [{"X": "TFS", "V": "accelerate", "Y": "transcription"}, {"X": "Spt4/5", "V": "accelerate", "Y": "transcription"}]
# [{"X": "Eosinophils", "V": "accelerate", "Y": "pathogenesis"}]
# [{"X": "membranes", "V": "accelerate", "Y": "amyloid formation"}]
# [{"X": "Homocysteine", "V": "accelerate", "Y": "skin aging"}]
# [{"X": "NLRP3 inflammasome", "V": "accelerate", "Y": "pathology"}, {"X": "NLRP3 inflammasome", "V": "accelerate", "Y": "IL-1\u03b2"}]
# [{"X": "glucosamine fibers", "V": "accelerate", "Y": "hemostatis"}]
# [{"X": "stem cells", "V": "accelerate", "Y": "wound healing"}]
# [{"X": "Cumulus cells", "V": "accelerate", "Y": "aging"}]
# [{"X": "Aluminium salts", "V": "accelerate", "Y": "peroxidation"}]
# [{"X": "foudnations", "V": "accelerate", "Y": "change"}, {"X": "foudnations", "V": "accelerate", "Y": "competence"}]
# [{"X": "Gangliosides", "V": "accelerate", "Y": "rat neonatal learning"}, {"X": "Gangliosides", "V": "accelerate", "Y": "levels"}]
# [{"X": "Semax", "V": "accelerate", "Y": "healing"}, {"X": "glyproline peptides", "V": "accelerate", "Y": "healing"}]
# [{"X": "engines", "V": "accelerate", "Y": "aging"}, {"X": "engines", "V": "accelerate", "Y": "disease"}]
# [{"X": "MIF-1", "V": "accelerate", "Y": "neuromotor"}, {"X": "MIF-1", "V": "accelerate", "Y": "EEG"}, {"X": "MIF-1", "V": "accelerate", "Y": "development"}]
# [{"X": "Distributed representations", "V": "accelerate", "Y": "evolution"}]
# [{"X": "Azelogycine", "V": "down-regulate", "Y": "mediators"}, {"X": "nicotinamide", "V": "down-regulate", "Y": "mediators"}]
# [{"X": "miR-214", "V": "down-regulate", "Y": "Necl-2/CADM1"}, {"X": "hypoxia", "V": "down-regulate", "Y": "Necl-2/CADM1"}]
# [{"X": "microRNAs let-7", "V": "down-regulate", "Y": "axon-guidance genes"}, {"X": "mir-9", "V": "down-regulate", "Y": "axon-guidance genes"}]
# [{"X": "carbon particles", "V": "down-regulate", "Y": "CYP1B1 expression"}]
# [{"X": "Probiotics", "V": "down-regulate", "Y": "genes"}]
# [{"X": "polyphenols", "V": "down-regulate", "Y": "stress protein"}]
# [{"X": "bmo-miR-0001", "V": "down-regulate", "Y": "expression"}, {"X": "bmo-miR-0015", "V": "down-regulate", "Y": "expression"}]
# [{"X": "suppressor cells", "V": "down-regulate", "Y": "L-selectin expression"}]
# [{"X": "Glucocorticoids", "V": "down-regulate", "Y": "somatostatin receptors"}]
# [{"X": "Glucocorticoids", "V": "down-regulate", "Y": "matrix proteins fibronectin"}, {"X": "Glucocorticoids", "V": "down-regulate", "Y": "matrix proteins fibulin-1"}, {"X": "Glucocorticoids", "V": "down-regulate", "Y": "matrix proteins fibulin-2"}]
# [{"X": "memory CTL", "V": "down-regulate", "Y": "molecule expression"}]
# [{"X": "MiR-126 restoration", "V": "down-regulate", "Y": "VEGF"}]
# [{"X": "miR-26a", "V": "down-regulate", "Y": "expression"}, {"X": "miR-214", "V": "down-regulate", "Y": "expression"}]
# [{"X": "IL-12", "V": "down-regulate", "Y": "B cell migration"}, {"X": "IL-18", "V": "down-regulate", "Y": "B cell migration"}]
# [{"X": "VIP", "V": "down-regulate", "Y": "CXCL10"}, {"X": "PACAP", "V": "down-regulate", "Y": "CXCL10"}]
# [{"X": "concentrations", "V": "down-regulate", "Y": "secretion"}]
# [{"X": "Flavonoids", "V": "down-regulate", "Y": "mediators"}]
# [{"X": "C-X-C Motif Ligand 1", "V": "down-regulates", "Y": "invasion"}]
# [{"X": "mechanisms", "V": "down-regulate", "Y": "SecA ATPase activity"}]
# [{"X": "metabolites", "V": "down-regulate", "Y": "receptor gamma"}]
# TP       : 1
# FP       : 135
# FN       : 134
# Precision: 0.0074
# Recall   : 0.0074
# F Score  : 0.0074
